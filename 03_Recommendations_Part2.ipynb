# %% [markdown]
# # Recommendations: Part 2
#
# In the 2nd part of our recommendations exercise, you will use the PageRank algorithm to make article recommendations to an author.
# Execute the code to import the libraries (remember to unset Reset all runtimes before running):

# %%
from py2neo import Graph
import pandas as pd

import matplotlib 
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# Update the cell below to use the IP Address, Bolt Port, and Password, as you did previously.

# %%
# Change the line of code below to use the Bolt URL,  and Password of your Neo4j database instance.
# graph = Graph("<Bolt URL>", auth=("neo4j", "<Password>")) 
 
graph = Graph("bolt://localhost:7687", auth=("neo4j", "letmein"))

# %% [markdown]
# ## PageRank
#
# [PageRank](https://neo4j.com/docs/graph-data-science/current/algorithms/page-rank/) is an algorithm that measures the transitive influence or connectivity of nodes. It can be computed by either iteratively distributing one node’s rank (originally based on degree) over its neighbors or by randomly traversing the graph and counting the frequency of hitting each node during these walks.
#
# Run this PageRank code over the whole graph to find out the most influential article in terms of citations:

# %%
query = """
CALL gds.pageRank.write({
  nodeProjection:'Article', 
  relationshipProjection:'CITED',
  writeProperty:'pagerank'})
"""
graph.run(query).data()
# Out:
# [{'nodePropertiesWritten': 51956,
#   'createMillis': 250,
#   'computeMillis': 578,
#   'postProcessingMillis': 40,
#   'writeMillis': 732,
#   'ranIterations': 20,
#   'didConverge': False,
#   'centralityDistribution': {'p1': 0.14999961853027344,
#    'max': 93.94335842132568,
#    'p5': 0.14999961853027344,
#    'p90': 0.2774991989135742,
#    'p50': 0.14999961853027344,
#    'p95': 0.43799686431884766,
#    'p10': 0.14999961853027344,
#    'p75': 0.14999961853027344,
#    'p99': 1.3121633529663086,
#    'p25': 0.14999961853027344,
#    'p100': 93.94335842132568,
#    'min': 0.14999961853027344,
#    'mean': 0.22228103009279077,
#    'stdDev': 0.6853762846438416},
#   'configuration': {'maxIterations': 20,
#    'writeConcurrency': 4,
#    'relationshipWeightProperty': None,
#    'cacheWeights': False,
#    'concurrency': 4,
#    'sourceNodes': [],
#    'writeProperty': 'pagerank',
#    'nodeLabels': ['*'],
#    'sudo': False,
#    'dampingFactor': 0.85,
#    'relationshipTypes': ['*'],
#    'tolerance': 1e-07}}]

# %% [markdown]
# This query stores a 'pagerank' property on each node. Execute this code to view the most influential articles:

# %%
query = """
MATCH (a:Article)
RETURN a.title as article,
       a.pagerank as score
ORDER BY score DESC 
LIMIT 10
"""
graph.run(query).to_data_frame()
# Out:
#                                                                                              article  \
# 0                             A method for obtaining digital signatures and public-key cryptosystems
# 1                                                       Secure communications over insecure channels
# 2                                                                                         Rough sets
# 3                                                        An axiomatic basis for computer programming
# 4  Pastry: Scalable, Decentralized Object Location, and Routing for Large-Scale Peer-to-Peer Systems
# 5                              SCRIBE: The Design of a Large-Scale Event Notification Infrastructure
# 6                                     A field study of the software design process for large systems
# 7                                                  Productivity factors and programming environments
# 8                                                        Analyzing medium-scale software development
# 9                                                                A Calculus of Communicating Systems
#
#    score
# 0 93.943
# 1 79.869
# 2 25.609
# 3 23.029
# 4 21.470
# 5 19.486
# 6 19.028
# 7 18.499
# 8 16.453
# 9 15.431

# %% [markdown]
# ## Personalized PageRank
#
# [Personalized PageRank](https://neo4j.com/docs/graph-data-science/current/algorithms/page-rank/#algorithms-page-rank-examples-personalised) is a variant of PageRank that allows us to find influential nodes based on a set of source nodes.
#
# For example, rather than finding the overall most influential articles, you could instead, find the most influential articles with respect to a given author.
# Execute this code to use a personalized PageRank algorithm:

# %%
query = """
MATCH (a:Author {name: $author})<-[:AUTHOR]-(article)-[:CITED]->(other)
WITH collect(article) + collect(other) AS sourceNodes
CALL gds.pageRank.stream({
  nodeProjection:'Article',
  relationshipProjection:'CITED',
  sourceNodes: sourceNodes})
YIELD nodeId, score
RETURN gds.util.asNode(nodeId).title AS article, score
ORDER BY score DESC
LIMIT 10
"""

author_name = "Peter G. Neumann"
graph.run(query, {"author": author_name}).to_data_frame()
# Out:
#                                                                          article  \
# 0                    A technique for software module specification with examples
# 1         A messy state of the union: taming the composite state machines of TLS
# 2  Risks of automation: a cautionary total-system perspective of our cyberfuture
# 3                                                              Risks of e-voting
# 4                                                             The foresight saga
# 5                                                    Public interest and the NII
# 6                                                     Crypto policy perspectives
# 7                                              Password security: a case history
# 8                                  The challenges of partially automated driving
# 9                        Proof techniques for hierarchically structured programs
#
#    score
# 0  0.359
# 1  0.332
# 2  0.278
# 3  0.278
# 4  0.278
# 5  0.278
# 6  0.278
# 7  0.278
# 8  0.268
# 9  0.248

# %% [markdown]
# ## Topic Sensitive Search
#
# You can also use Personalized PageRank to do 'Topic Specific PageRank'.
#
# When an author is searching for articles to read, they want that search to take themselves as authors into account. Two authors using the same search term would expect to see different results depending on their area of research.
#
# Create a full text search index on the 'title' and 'abstract' properties of all nodes that have the label 'Article' by executing this code:

# %%
query = """
    CALL db.index.fulltext.createNodeIndex('articles', ['Article'], ['title', 'abstract'])
"""
graph.run(query).data()
# Out:
# []

# %% [markdown]
# Check that the full text index has been created by running the following query:

# %%
query = """
CALL db.indexes()
YIELD name, state, populationPercent, uniqueness, type, entityType, labelsOrTypes, properties, provider
WHERE type = "FULLTEXT"
RETURN *
"""
graph.run(query).to_data_frame()
# Out:
#   entityType labelsOrTypes      name  populationPercent         properties  \
# 0       NODE     [Article]  articles            100.000  [title, abstract]
#
#        provider   state      type uniqueness
# 0  fulltext-1.0  ONLINE  FULLTEXT  NONUNIQUE

# %% [markdown]
# You can search the full text index like this:

# %%
query = """
CALL db.index.fulltext.queryNodes("articles", "open source")
YIELD node, score
RETURN node.title as article, score, [(author)<-[:AUTHOR]-(node) | author.name] AS authors
LIMIT 10
"""
graph.run(query).to_data_frame()
# Out:
#                                                                                        article  \
# 0                                                                      Progressive open source
# 1         Open source application spaces: the 5th workshop on open source software engineering
# 2  Reusing Open-Source Software and Practices: The Impact of Open-Source on Commercial Vendors
# 3                                                        From Research Software to Open Source
# 4                                             The comment density of open source software code
# 5                                                Software architecture in an open source world
# 6                                              Managing a corporate open source software asset
# 7                       Organizational adoption of open source software: barriers and remedies
# 8                                                       IBM's pragmatic embrace of open source
# 9                                   Analysing the reliability of Open Source software projects
#
#    score  \
# 0 11.740
# 1 11.150
# 2 11.016
# 3 10.328
# 4 10.292
# 5 10.250
# 6 10.187
# 7  9.894
# 8  9.849
# 9  9.683
#
#                                                                                authors
# 0                         [Jamie Dinkelacker, Pankaj K. Garg, Dean Nelson, Rob Miller]
# 1  [Joseph Feller, Scott A. Hissam, Brian Fitzgerald, Krishna K Lakhani, Walt Scacchi]
# 2                                                         [Alan W. Brown, Grady Booch]
# 3                                                                    [Susan L. Graham]
# 4                                                        [Oliver Arafati, Dirk Riehle]
# 5                                                                    [Roy T. Fielding]
# 6                                 [James D. Herbsleb, Vijay K. Gurbani, Anita Garvert]
# 7                                      [Anol Bhattacherjee, Areej M. Yassin, Del Nagy]
# 8                                                                   [Pamela Samuelson]
# 9                                                  [Lerina Aversano, Maria Tortorella]

# %% [markdown]
# Here is a query to find the authors that have published the most articles on 'open source':

# %%
query = """
CALL db.index.fulltext.queryNodes("articles", "open source")
YIELD node, score
MATCH (node)-[:AUTHOR]->(author)
RETURN author.name as author, sum(score) AS totalScore, collect(node.title) AS articles
ORDER By totalScore DESC
LIMIT 20
"""

graph.run(query).to_data_frame()
# Out:
#                      author  totalScore  \
# 0          Denys Poshyvanyk      51.326
# 1          Brian Fitzgerald      49.406
# 2             Joseph Feller      45.596
# 3         James D. Herbsleb      38.699
# 4            Gail C. Murphy      36.538
# 5              Walt Scacchi      34.336
# 6           Ahmed E. Hassan      33.800
# 7          Daniel M. German      33.478
# 8       Martin P. Robillard      33.017
# 9           Scott A. Hissam      32.555
# 10           Andrian Marcus      29.921
# 11          Gabriele Bavota      28.954
# 12  Margaret-Anne D. Storey      28.914
# 13          Collin McMillan      27.687
# 14    Massimiliano Di Penta      27.144
# 15            Katsuro Inoue      27.047
# 16            Rocco Oliveto      26.247
# 17            Audris Mockus      25.747
# 18            Michele Lanza      25.509
# 19            John Hatcliff      25.204
#
#                                                                                                articles
# 0   [Machine learning-based detection of open source license exceptions, Recommending source code fo...
# 1   [Open source application spaces: the 5th workshop on open source software engineering, The 3rd w...
# 2   [Open source application spaces: the 5th workshop on open source software engineering, The 3rd w...
# 3   [Managing a corporate open source software asset, A case study of a corporate open source develo...
# 4   [Who should fix this bug, Hipikat: recommending pertinent software development artifacts, FEAT a...
# 5   [Open source application spaces: the 5th workshop on open source software engineering, Experienc...
# 6   [A study of the quality-impacting practices of modern code review at Sony mobile, An empirical s...
# 7   [Machine learning-based detection of open source license exceptions, Open source-style collabora...
# 8   [Disseminating architectural knowledge on open-source projects: a case study of the book "archit...
# 9   [Open source application spaces: the 5th workshop on open source software engineering, The 3rd w...
# 10  [3D visualization for concept location in source code, Supporting program comprehension with sou...
# 11  [Machine learning-based detection of open source license exceptions, Query quality prediction an...
# 12  [Understanding broadcast based peer review on open source software projects, Peer Review on Open...
# 13  [Recommending source code for use in rapid software prototypes, Searching, selecting, and synthe...
# 14  [Machine learning-based detection of open source license exceptions, An empirical study on the d...
# 15  [Very-Large Scale Code Clone Analysis and Visualization of Open Source Programs Using Distribute...
# 16  [Query quality prediction and reformulation for source code search: the refoqus tool, An empiric...
# 17  [A case study of open source software development: the Apache server, Does the initial environme...
# 18  [Linking e-mails and source code artifacts, The small project observatory: a tool for reverse en...
# 19  [Bandera: extracting finite-state models from Java source code, Bandera: a source-level interfac...

# %% [markdown]
# Next, use full text search and Personalized PageRank to find interesting articles for different authors:

# %%
query = """
MATCH (a:Author {name: $author})<-[:AUTHOR]-(article)-[:CITED]->(other)
WITH a, collect(article) + collect(other) AS sourceNodes
CALL gds.pageRank.stream({
  nodeQuery: 'CALL db.index.fulltext.queryNodes("articles", $searchTerm)
   YIELD node, score
   RETURN id(node) as id',
  relationshipQuery: 'MATCH (a1:Article)-[:CITED]->(a2:Article) 
   RETURN id(a1) as source,id(a2) as target', 
  sourceNodes: sourceNodes,
  validateRelationships:false,
  parameters: {searchTerm: $searchTerm}})
YIELD nodeId, score
WITH gds.util.asNode(nodeId) AS n, score
WHERE not(exists((a)<-[:AUTHOR]-(n))) AND score > 0
RETURN n.title as article, score, [(n)-[:AUTHOR]->(author) | author.name][..5] AS authors
order by score desc limit 10
"""

params = {"author": "Tao Xie", "searchTerm": "open source"}
graph.run(query, params).to_data_frame()
# Out:
#                                                                                                article  \
# 0                                             Static detection of cross-site scripting vulnerabilities
# 1                                                                              Who should fix this bug
# 2                        Automated, contract-based user testing of commercial-off-the-shelf components
# 3                Concern graphs: finding and describing concerns using structural program dependencies
# 4                                             Characterizing logging practices in open-source software
# 5                                                Conceptual module querying for software reengineering
# 6                                        Bandera: extracting finite-state models from Java source code
# 7  AsDroid: detecting stealthy behaviors in Android applications by user interface and program beha...
# 8                                                                          Semantics-based code search
# 9                                                                     EXSYST: search-based GUI testing
#
#    score  \
# 0  0.386
# 1  0.278
# 2  0.278
# 3  0.278
# 4  0.278
# 5  0.236
# 6  0.150
# 7  0.150
# 8  0.150
# 9  0.128
#
#                                                                      authors
# 0                                             [Zhendong Su, Gary Wassermann]
# 1                                  [Gail C. Murphy, John Anvik, Lyndon Hiew]
# 2                          [Yvan Labiche, Michal M. Sówka, Lionel C. Briand]
# 3                                      [Martin P. Robillard, Gail C. Murphy]
# 4                                    [Yuanyuan Zhou, Ding Yuan, Soyeon Park]
# 5                                    [Elisa L. A. Baniassad, Gail C. Murphy]
# 6  [James C. Corbett, Shawn Laubach, John Hatcliff, Robby, Matthew B. Dwyer]
# 7              [Xiangyu Zhang, Bin Liang, Jianjun Huang, Lin Tan, Peng Wang]
# 8                                                          [Steven P. Reiss]
# 9                             [Gordon Fraser, Florian Gross, Andreas Zeller]

# %% [markdown]
# Execute the same query with a different author:

# %%
params = {"author": "Marco Aurélio Gerosa", "searchTerm": "open source"}
graph.run(query, params).to_data_frame()
# Out:
#                                                                                               article  \
# 0                        Toward an understanding of the motivation of open source software developers
# 1                                      Hipikat: recommending pertinent software development artifacts
# 2                                     Version Sensitive Editing: Change History as a Programming Tool
# 3                                Which bug should I fix: helping new developers onboard a new project
# 4  Tesseract: Interactive visual exploration of socio-technical relationships in software development
# 5                 Role Migration and Advancement Processes in OSSD Projects: A Comparative Case Study
# 6                                        Does the initial environment impact the future of developers
# 7       Unifying artifacts and activities in a visual tool for distributed software development teams
# 8                                 A case study of open source software development: the Apache server
# 9          A case study of the evolution of Jun: an object-oriented open-source 3D multimedia library
#
#    score  \
# 0  0.388
# 1  0.322
# 2  0.274
# 3  0.239
# 4  0.203
# 5  0.175
# 6  0.175
# 7  0.173
# 8  0.110
# 9  0.110
#
#                                                                              authors
# 0                                                       [Yunwen Ye, Kouichi Kishida]
# 1                                                   [Gail C. Murphy, Davor Cubranic]
# 2                                                                  [David L. Atkins]
# 3                                                        [Jianguo Wang, Anita Sarma]
# 4               [Patrick Wagstrom, Larry Maccherone, James D. Herbsleb, Anita Sarma]
# 5                                                       [Chris Jensen, Walt Scacchi]
# 6                                                      [Audris Mockus, Minghui Zhou]
# 7                                                      [Jon Froehlich, Paul Dourish]
# 8                                   [Audris Mockus, James D. Herbsleb, Roy Fielding]
# 9  [A. Takasbima, Kouichi Kishida, Yoshiyuki Nishinaka, Kaoru Hayashi, Atsushi Aoki]
